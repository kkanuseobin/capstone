# %%
### chromedriver 필요!!

# 필요한 라이브러리 불러오기
from selenium import webdriver
from urllib.request import urlopen
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import urllib.request
import os



# 크롬 웹드라이버 연결
driver = webdriver.Chrome()
driver.get("https://www.google.co.kr/imghp?hl=ko&ogbl")


# 검색어 입력하기
search = input("검색어 입력하세요. : ")
elem = driver.find_element(By.NAME,"q")
elem.send_keys(search)
elem.send_keys(Keys.RETURN)

# 이미지 저장할 폴더 생성
if not os.path.isdir(str(search)+"/"):
    os.makedirs(str(search)+"/")


# 스크롤 끝까지 내리기
SCROLL_PAUSE_TIME = 1

last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(SCROLL_PAUSE_TIME)
    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        try:
            driver.find_elements(By.CSS_SELECTOR,".mye4qd").click()
        except:
            break
    last_height = new_height


# 5. 이미지 찾아서 원본 파일로 저장하기
images = driver.find_elements(By.CSS_SELECTOR,".rg_i.Q4LuWd")
count = 1

for image in images:
    try:
        image.click()
        time.sleep(2)
        imgUrl  = driver.find_element(By.XPATH, '//*[@id="Sva75c"]/div[2]/div/div[2]/div[2]/div[2]/c-wiz/div/div[1]/div[2]/div[2]/div/a/img').get_attribute("src")
        urllib.request.urlretrieve(imgUrl, search+"/" + search + "_" + str(count) + ".jpg")
        print("Image saved: crawling_{}.jpg".format(count))
        count += 1
    except:
        pass

driver.close()
# Out:
# 검색어 입력하세요. : 전동킥보드 판매
# Image saved: scooter_1.jpg
# Image saved: scooter_2.jpg
# Image saved: scooter_3.jpg
# Image saved: scooter_4.jpg
# Image saved: scooter_5.jpg
# Image saved: scooter_6.jpg
# Image saved: scooter_7.jpg
# Image saved: scooter_8.jpg
# Image saved: scooter_9.jpg
# Image saved: scooter_10.jpg
# Image saved: scooter_11.jpg
# Image saved: scooter_12.jpg
# Image saved: scooter_13.jpg
# Image saved: scooter_14.jpg
# Image saved: scooter_15.jpg
# Image saved: scooter_16.jpg
# Image saved: scooter_17.jpg
# Image saved: scooter_18.jpg
# Image saved: scooter_19.jpg
# Image saved: scooter_20.jpg
# Image saved: scooter_21.jpg
# Image saved: scooter_22.jpg
# Image saved: scooter_23.jpg
# Image saved: scooter_24.jpg
# Image saved: scooter_25.jpg
# Image saved: scooter_26.jpg
# Image saved: scooter_27.jpg
# Image saved: scooter_28.jpg
# Image saved: scooter_29.jpg
# Image saved: scooter_30.jpg
# Image saved: scooter_31.jpg
# Image saved: scooter_32.jpg
# Image saved: scooter_33.jpg
# Image saved: scooter_34.jpg
# Image saved: scooter_35.jpg
# Image saved: scooter_36.jpg
# Image saved: scooter_37.jpg
# Image saved: scooter_38.jpg
# Image saved: scooter_39.jpg
# Image saved: scooter_40.jpg
# Image saved: scooter_41.jpg
# Image saved: scooter_42.jpg
# Image saved: scooter_43.jpg
# Image saved: scooter_44.jpg
# Image saved: scooter_45.jpg
# Image saved: scooter_46.jpg
# Image saved: scooter_47.jpg
